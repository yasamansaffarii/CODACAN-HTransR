# %%
# !cp -r /content/drive/MyDrive/DialogDQN-Variants1/* /content/drive/MyDrive/CODACAN+HTransR

# %%
# !git clone https://github.com/yasamansaffarii/CODACAN-HTransR.git
# Out:
# Cloning into 'CODACAN-HTransR'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 5.81 KiB | 850.00 KiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !cp -r /content/drive/MyDrive/DialogDQN-Variants1/* /content/drive/MyDrive/CODACAN-HTransR/

# %%
cd /content/drive/MyDrive/CODACAN-HTransR
# Out:
# /content/drive/MyDrive/CODACAN-HTransR

# %%
# Step 5: Set up Git configuration (if not already done)
# !git config --global user.name "yasamansaffarii"  # Replace with your GitHub username
# !git config --global user.email "yasamansaffarii@gmail.com"  # Replace with your GitHub email

# Step 6: Add the changes
# !cd /content/drive/MyDrive/CODACAN-HTransR && git add .  # Navigate to the folder and add all files

# Step 7: Commit the changes
# !cd /content/drive/MyDrive/CODACAN-HTransR && git commit -m "Add project files from Google Drive"

# %%
# Step 8: Push the changes to GitHub using your Personal Access Token (replace the token and repo info)
# Step 8: Push the changes to GitHub using your Personal Access Token (replace the token and repo info)
# !cd /content/drive/MyDrive/CODACAN-HTransR && git push https://ghp_SReQvUYUr*************1MJ6R1@github.com/yasamansaffarii/CODACAN-HTransR.git main
# Out:
# Enumerating objects: 318, done.
# Counting objects: 100% (318/318), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (301/301), done.
# Writing objects: 100% (316/316), 524.52 MiB | 7.39 MiB/s, done.
# Total 316 (delta 42), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (42/42), done.
# To https://github.com/yasamansaffarii/CODACAN-HTransR.git
#    d9cf28f..825e730  main -> main

# %%
#simple res
# !python run.py --agt 12 --usr 2 --max_turn 40 --write_model_dir ./deep_dialog/checkpoints/ --kb_path ./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p --goal_file_path ./deep_dialog/data_restaurant/user_goals_first.v1.p --act_set ./deep_dialog/data_restaurant/dia_acts.txt --dict_path ./deep_dialog/data_restaurant/slot_dict.v2.p --nlg_model_path ./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p --nlu_model_path ./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p --diaact_nl_pairs ./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json --intent_err_prob 0.00 --slot_err_prob 0.00 --episodes 500 --act_level 0 --run_mode 0 --cmd_input_mode 0
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_restaurant/slot_dict.v2.p",
#   "kb_path": "./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_restaurant/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_restaurant/restaurant_slots.txt",
#   "goal_file_path": "./deep_dialog/data_restaurant/user_goals_first.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json",
#   "max_turn": 40,
#   "episodes": 500,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 12,
#   "usr": 2,
#   "epsilon": 0,
#   "nlg_model_path": "./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p",
#   "act_level": 0,
#   "run_mode": 0,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 1000,
#   "dqn_hidden_size": 60,
#   "batch_size": 16,
# ...

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/MiuLab/DialogDQN-Variants.git
# Out:
# Cloning into 'DialogDQN-Variants'...
# remote: Enumerating objects: 141, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 141 (delta 8), reused 8 (delta 3), pack-reused 123 (from 1)
# Receiving objects: 100% (141/141), 46.89 MiB | 10.78 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# Updating files: 100% (94/94), done.

# %%
cd /content/drive/MyDrive/DialogDQN-Variants
# Out:
# /content/drive/MyDrive/DialogDQN-Variants

# %%
import os
import json

# Create directory if it doesn't exist
output_dir = './movie/dqn/0'
os.makedirs(output_dir, exist_ok=True)
# Create directory if it doesn't exist
output_dir = './restaurant/dqn/0'
os.makedirs(output_dir, exist_ok=True)
# Create directory if it doesn't exist
output_dir = './taxi/dqn/0'
os.makedirs(output_dir, exist_ok=True)

# %%
# !pip install 2to3

# %%
!2to3 -w /content/drive/MyDrive/DialogDQN-Variants
# Out:
# RefactoringTool: Skipping optional fixer: buffer
# RefactoringTool: Skipping optional fixer: idioms
# RefactoringTool: Skipping optional fixer: set_literal
# RefactoringTool: Skipping optional fixer: ws_comma
# RefactoringTool: Refactored /content/drive/MyDrive/DialogDQN-Variants/run.py
# --- /content/drive/MyDrive/DialogDQN-Variants/run.py	(original)
# +++ /content/drive/MyDrive/DialogDQN-Variants/run.py	(refactored)
# @@ -15,19 +15,19 @@
#  user_goals_first_turn_template.part.movie.v1.p: a subset of user goal. [Please use this one, the upper bound success rate on movie_kb.1k.json is 0.9765.]
#
#  Commands:
# -Rule: python run.py --agt 5 --usr 1 --max_turn 40 --episodes 150 --kb_path .\deep_dialog\data\movie_kb.1k.p --goal_file_path .\deep_dialog\data\user_goals_first_turn_template.part.movie.v1.p --intent_err_prob 0.00 --slot_err_prob 0.00 --episodes 500 --act_level 1 --run_mode 1
# ...

# %%
#AC-DISTduel
# !bash script/restaurant.sh
# Out:
# bash: script/restaurant.sh: No such file or directory

# %%
#AC-DISTduel
# !bash script/restaurant.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_restaurant/slot_dict.v2.p",
#   "kb_path": "./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_restaurant/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_restaurant/restaurant_slots.txt",
#   "goal_file_path": "./deep_dialog/data_restaurant/user_goals_first.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 12,
#   "usr": 2,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
# ...

# %%
from google.colab import drive
import os
import shutil

# Step 2: Define source and destination paths
source_folder = '/content/drive/MyDrive/DialogDQN-Variants'  # Replace with your source folder name
destination_folder = '/content/drive/MyDrive/DialogDQN-Variants1'  # Replace with your target folder name

# Step 3: Check if the source folder exists
if not os.path.exists(source_folder):
    print(f"Source folder '{source_folder}' does not exist.")
else:
    # Step 4: Duplicate the folder
    try:
        shutil.copytree(source_folder, destination_folder)
        print(f"Folder duplicated successfully to '{destination_folder}'")
    except FileExistsError:
        print(f"Destination folder '{destination_folder}' already exists. Choose a different name.")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Folder duplicated successfully to '/content/drive/MyDrive/DialogDQN-Variants1'

# %%
#AC-DISTduel
# !bash script/restaurant.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_restaurant/slot_dict.v2.p",
#   "kb_path": "./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_restaurant/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_restaurant/restaurant_slots.txt",
#   "goal_file_path": "./deep_dialog/data_restaurant/user_goals_first.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 12,
#   "usr": 2,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
# ...

# %%
#AC-DISTduel
# !bash script/restaurant.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_restaurant/slot_dict.v2.p",
#   "kb_path": "./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_restaurant/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_restaurant/restaurant_slots.txt",
#   "goal_file_path": "./deep_dialog/data_restaurant/user_goals_first.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 12,
#   "usr": 2,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
# ...

# %%
#AC-DISTduel=3
# !bash script/taxi.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_taxi/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_taxi/taxi.kb.2k.v1.p",
#   "act_set": "./deep_dialog/data_taxi/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_taxi/taxi_slots.txt",
#   "goal_file_path": "./deep_dialog/data_taxi/user_goals_first.v4.p",
#   "diaact_nl_pairs": "./deep_dialog/data_taxi/sim_dia_act_nl_pairs.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 13,
#   "usr": 3,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/taxi/lstm_tanh_[1532457558.95]_95_99_194_0.985.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/taxi/lstm_[1532583523.63]_88_99_400_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
#   "predict_mode": false,
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#AC-DISTduel=3
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants1
# Out:
# /content/drive/MyDrive/DialogDQN-Variants1

# %%
#AC-DISTduel=7
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 50000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
#AC-DISTduel=7
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants1
# Out:
# /content/drive/MyDrive/DialogDQN-Variants1

# %%
#AC-DISTduel=7=====>ep=70 , succ=0.03 rew: -45
# !bash script/taxi.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_taxi/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_taxi/taxi.kb.2k.v1.p",
#   "act_set": "./deep_dialog/data_taxi/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_taxi/taxi_slots.txt",
#   "goal_file_path": "./deep_dialog/data_taxi/user_goals_first.v4.p",
#   "diaact_nl_pairs": "./deep_dialog/data_taxi/sim_dia_act_nl_pairs.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 13,
#   "usr": 3,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/taxi/lstm_tanh_[1532457558.95]_95_99_194_0.985.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/taxi/lstm_[1532583523.63]_88_99_400_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
#   "predict_mode": false,
# ...

# %%
#l=7
# !bash script/restaurant.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_restaurant/slot_dict.v2.p",
#   "kb_path": "./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_restaurant/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_restaurant/restaurant_slots.txt",
#   "goal_file_path": "./deep_dialog/data_restaurant/user_goals_first.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 12,
#   "usr": 2,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants1
# Out:
# /content/drive/MyDrive/DialogDQN-Variants1

# %%
#l=5
# !bash script/restaurant.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_restaurant/slot_dict.v2.p",
#   "kb_path": "./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_restaurant/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_restaurant/restaurant_slots.txt",
#   "goal_file_path": "./deep_dialog/data_restaurant/user_goals_first.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 12,
#   "usr": 2,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants1
# Out:
# /content/drive/MyDrive/DialogDQN-Variants1

# %%
#l=5
# !bash script/taxi.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_taxi/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_taxi/taxi.kb.2k.v1.p",
#   "act_set": "./deep_dialog/data_taxi/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_taxi/taxi_slots.txt",
#   "goal_file_path": "./deep_dialog/data_taxi/user_goals_first.v4.p",
#   "diaact_nl_pairs": "./deep_dialog/data_taxi/sim_dia_act_nl_pairs.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 13,
#   "usr": 3,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/taxi/lstm_tanh_[1532457558.95]_95_99_194_0.985.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/taxi/lstm_[1532583523.63]_88_99_400_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
#   "predict_mode": false,
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants1
# Out:
# /content/drive/MyDrive/DialogDQN-Variants1

# %%
#l=5
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
#l=5
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
#l=7
# !bash script/taxi.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_taxi/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_taxi/taxi.kb.2k.v1.p",
#   "act_set": "./deep_dialog/data_taxi/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_taxi/taxi_slots.txt",
#   "goal_file_path": "./deep_dialog/data_taxi/user_goals_first.v4.p",
#   "diaact_nl_pairs": "./deep_dialog/data_taxi/sim_dia_act_nl_pairs.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 13,
#   "usr": 3,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/taxi/lstm_tanh_[1532457558.95]_95_99_194_0.985.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/taxi/lstm_[1532583523.63]_88_99_400_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
#   "predict_mode": false,
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants
# Out:
# /content/drive/MyDrive/DialogDQN-Variants

# %%
#l=1
# !bash script/taxi.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_taxi/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_taxi/taxi.kb.2k.v1.p",
#   "act_set": "./deep_dialog/data_taxi/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_taxi/taxi_slots.txt",
#   "goal_file_path": "./deep_dialog/data_taxi/user_goals_first.v4.p",
#   "diaact_nl_pairs": "./deep_dialog/data_taxi/sim_dia_act_nl_pairs.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 13,
#   "usr": 3,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/taxi/lstm_tanh_[1532457558.95]_95_99_194_0.985.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/taxi/lstm_[1532583523.63]_88_99_400_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
#   "predict_mode": false,
# ...

# %%
#l=1
# !bash script/restaurant.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_restaurant/slot_dict.v2.p",
#   "kb_path": "./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_restaurant/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_restaurant/restaurant_slots.txt",
#   "goal_file_path": "./deep_dialog/data_restaurant/user_goals_first.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 12,
#   "usr": 2,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
# ...

# %%
#l=1
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants
# Out:
# /content/drive/MyDrive/DialogDQN-Variants

# %%
#l=1, simple
# !bash script/movie.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Successful Dialog!
# cur bellman err 109.9503, experience replay pool 2890
# simulation success rate 0.43, ave reward -2.05, ave turns 29.3, i_r 0.0
# simulation success rate 0.47, ave reward 3.17, ave turns 28.46, i_r 0.0
# Simulation success rate 0.47, Ave reward 3.17, Ave turns 28.46, Best success rate 0.52
# intrinsic reward: 0.0
# Progress: 76 / 200, Success rate: 31 / 76 Avg reward: -4.25 Avg turns: 28.39
# Epsilon: 0.0000
# Episode: 76
# Failed Dialog!
# cur bellman err 109.3836, experience replay pool 4338
# simulation success rate 0.44, ave reward -0.68, ave turns 28.96, i_r 0.0
# simulation success rate 0.36, ave reward -11.4, ave turns 31.2, i_r 0.0
# Simulation success rate 0.36, Ave reward -11.4, Ave turns 31.2, Best success rate 0.52
# intrinsic reward: 0.0
# Progress: 77 / 200, Success rate: 31 / 77 Avg reward: -4.97 Avg turns: 28.57
# Epsilon: 0.0000
# Episode: 77
# Failed Dialog!
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants
# Out:
# /content/drive/MyDrive/DialogDQN-Variants

# %%
#l=1, simple
# !bash script/taxi.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_taxi/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_taxi/taxi.kb.2k.v1.p",
#   "act_set": "./deep_dialog/data_taxi/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_taxi/taxi_slots.txt",
#   "goal_file_path": "./deep_dialog/data_taxi/user_goals_first.v4.p",
#   "diaact_nl_pairs": "./deep_dialog/data_taxi/sim_dia_act_nl_pairs.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 13,
#   "usr": 3,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/taxi/lstm_tanh_[1532457558.95]_95_99_194_0.985.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/taxi/lstm_[1532583523.63]_88_99_400_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
#   "predict_mode": false,
# ...

# %%
#l=1, simple
# !bash script/restaurant.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_restaurant/slot_dict.v2.p",
#   "kb_path": "./deep_dialog/data_restaurant/restaurant.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_restaurant/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_restaurant/restaurant_slots.txt",
#   "goal_file_path": "./deep_dialog/data_restaurant/user_goals_first.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_restaurant/sim_dia_act_nl_pairs.v2.json",
#   "max_turn": 30,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 12,
#   "usr": 2,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/restaurant/lstm_tanh_[1532068150.19]_98_99_294_0.983.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/restaurant/lstm_[1532107808.26]_68_74_20_0.997.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 10000,
#   "dqn_hidden_size": 80,
# ...

# %%
cd /content/drive/MyDrive/DialogDQN-Variants1
# Out:
# /content/drive/MyDrive/DialogDQN-Variants1

# %%
#l=5, simple rep:100000
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 100000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
#l=5, simple rep:50000
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 100000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
#l=5, simple rep:50000
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 50000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...

# %%
#l=5, simple rep:100000
# !bash script/movie.sh
# Out:
# Dialog Parameters:
# {
#   "dict_path": "./deep_dialog/data_movie/slot_dict.v1.p",
#   "kb_path": "./deep_dialog/data_movie/movie.kb.1k.v1.p",
#   "act_set": "./deep_dialog/data_movie/dia_acts.txt",
#   "slot_set": "./deep_dialog/data_movie/slot_set.txt",
#   "goal_file_path": "./deep_dialog/data_movie/user_goals_first_turn_template.part.movie.v1.p",
#   "diaact_nl_pairs": "./deep_dialog/data_movie/dia_act_nl_pairs.v7.json",
#   "max_turn": 40,
#   "episodes": 200,
#   "slot_err_prob": 0.0,
#   "slot_err_mode": 0,
#   "intent_err_prob": 0.0,
#   "agt": 9,
#   "usr": 1,
#   "epsilon": 0.0,
#   "nlg_model_path": "./deep_dialog/models/nlg/movie/lstm_tanh_[1533529279.91]_87_99_199_0.988.p",
#   "nlu_model_path": "./deep_dialog/models/nlu/movie/lstm_[1533588045.3]_38_38_240_0.998.p",
#   "act_level": 0,
#   "run_mode": 3,
#   "auto_suggest": 0,
#   "cmd_input_mode": 0,
#   "experience_replay_pool_size": 100000,
#   "dqn_hidden_size": 80,
#   "batch_size": 16,
#   "gamma": 0.95,
# ...
